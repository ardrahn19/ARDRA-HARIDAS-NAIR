# %% [markdown]
# <a href="https://colab.research.google.com/github/ardrahn19/ARDRA-HARIDAS-NAIR/blob/main/Phase1_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Phase 1 - Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#1.Loading the dataset

data = pd.read_csv( "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/VerbAgg.csv")
data.head(20)
# Out:
#     rownames  Anger Gender         item     resp  id  btype   situ  mode r2
# 0          1     20      M  S1WantCurse       no   1  curse  other  want  N
# 1          2     11      M  S1WantCurse       no   2  curse  other  want  N
# 2          3     17      F  S1WantCurse  perhaps   3  curse  other  want  Y
# 3          4     21      F  S1WantCurse  perhaps   4  curse  other  want  Y
# 4          5     17      F  S1WantCurse  perhaps   5  curse  other  want  Y
# 5          6     21      F  S1WantCurse      yes   6  curse  other  want  Y
# 6          7     39      F  S1WantCurse      yes   7  curse  other  want  Y
# 7          8     21      F  S1WantCurse       no   8  curse  other  want  N
# 8          9     24      F  S1WantCurse       no   9  curse  other  want  N
# 9         10     16      F  S1WantCurse      yes  10  curse  other  want  Y
# 10        11     15      F  S1WantCurse  perhaps  11  curse  other  want  Y
# 11        12     18      F  S1WantCurse      yes  12  curse  other  want  Y
# 12        13     36      M  S1WantCurse      yes  13  curse  other  want  Y
# 13        14     22      M  S1WantCurse      yes  14  curse  other  want  Y
# 14        15     16      F  S1WantCurse  perhaps  15  curse  other  want  Y
# 15        16     18      F  S1WantCurse  perhaps  16  curse  other  want  Y
# 16        17     23      F  S1WantCurse  perhaps  17  curse  other  want  Y
# 17        18     16      F  S1WantCurse  perhaps  18  curse  other  want  Y
# 18        19     21      F  S1WantCurse       no  19  curse  other  want  N
# 19        20     25      F  S1WantCurse  perhaps  20  curse  other  want  Y

# %%
#2.Applying basic statistical analysis

print("Shape of the Dataset:")
print(data.shape)


print("\nColumn Names:")
print(data.columns)


print("\nDataset Information:")
data.info()


print("\nStatistical Summary:")
print(data.describe())


print("\nMean:")
print(data.mean(numeric_only=True))


print("\nMedian:")
print(data.median(numeric_only=True))


print("\nMode:")
print(data.mode())


print("\nStandard Deviation:")
print(data.std(numeric_only=True))


print("\nMinimum Values:")
print(data.min(numeric_only=True))


print("\nMaximum Values:")
print(data.max(numeric_only=True))


print("\nNumber of Unique Values:")
print(data.nunique())


print("\nColumn Names:")
print(data.columns)


print("\nData Types:")
print(data.dtypes)
# Out:
# Shape of the Dataset:
# (7584, 10)
#
# Column Names:
# Index(['rownames', 'Anger', 'Gender', 'item', 'resp', 'id', 'btype', 'situ',
#        'mode', 'r2'],
#       dtype='object')
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7584 entries, 0 to 7583
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  7584 non-null   int64
#  1   Anger     7584 non-null   int64
#  2   Gender    7584 non-null   object
#  3   item      7584 non-null   object
#  4   resp      7584 non-null   object
#  5   id        7584 non-null   int64
#  6   btype     7584 non-null   object
#  7   situ      7584 non-null   object
#  8   mode      7584 non-null   object
#  9   r2        7584 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 592.6+ KB
#
# Statistical Summary:
#           rownames        Anger         id
# count  7584.000000  7584.000000  7584.0000
# mean   3792.500000    20.003165   158.5000
# std    2189.456554     4.841139    91.2269
# min       1.000000    11.000000     1.0000
# 25%    1896.750000    17.000000    79.7500
# 50%    3792.500000    19.000000   158.5000
# 75%    5688.250000    23.000000   237.2500
# max    7584.000000    39.000000   316.0000
#
# Mean:
# rownames    3792.500000
# Anger         20.003165
# id           158.500000
# dtype: float64
#
# Median:
# rownames    3792.5
# Anger         19.0
# id           158.5
# dtype: float64
#
# Mode:
#       rownames  Anger Gender         item resp   id  btype   situ  mode   r2
# 0            1   19.0      F    S1DoCurse   no  1.0  curse  other    do    N
# 1            2    NaN    NaN    S1DoScold  NaN  2.0  scold   self  want  NaN
# 2            3    NaN    NaN    S1DoShout  NaN  3.0  shout    NaN   NaN  NaN
# 3            4    NaN    NaN  S1WantCurse  NaN  4.0    NaN    NaN   NaN  NaN
# 4            5    NaN    NaN  S1WantScold  NaN  5.0    NaN    NaN   NaN  NaN
# ...        ...    ...    ...          ...  ...  ...    ...    ...   ...  ...
# 7579      7580    NaN    NaN          NaN  NaN  NaN    NaN    NaN   NaN  NaN
# 7580      7581    NaN    NaN          NaN  NaN  NaN    NaN    NaN   NaN  NaN
# 7581      7582    NaN    NaN          NaN  NaN  NaN    NaN    NaN   NaN  NaN
# 7582      7583    NaN    NaN          NaN  NaN  NaN    NaN    NaN   NaN  NaN
# 7583      7584    NaN    NaN          NaN  NaN  NaN    NaN    NaN   NaN  NaN
#
# [7584 rows x 10 columns]
#
# Standard Deviation:
# rownames    2189.456554
# Anger          4.841139
# id            91.226900
# dtype: float64
#
# Minimum Values:
# rownames     1
# Anger       11
# id           1
# dtype: int64
#
# Maximum Values:
# rownames    7584
# Anger         39
# id           316
# dtype: int64
#
# Number of Unique Values:
# rownames    7584
# Anger         26
# Gender         2
# item          24
# resp           3
# id           316
# btype          3
# situ           2
# mode           2
# r2             2
# dtype: int64
#
# Column Names:
# Index(['rownames', 'Anger', 'Gender', 'item', 'resp', 'id', 'btype', 'situ',
#        'mode', 'r2'],
#       dtype='object')
#
# Data Types:
# rownames     int64
# Anger        int64
# Gender      object
# item        object
# resp        object
# id           int64
# btype       object
# situ        object
# mode        object
# r2          object
# dtype: object

# %%
#3 Handling Missing Data

print("Missing Values:")
print(data.isnull().sum())

print("\nNon-Missing Values:")
print(data.notnull().sum())


print("\nTotal Missing Values:")
print(data.isnull().sum().sum())


print("\nCount of Non-Missing Values:")
print(data.count())


data_drop = data.dropna()

print("\nShape After dropna():")
print(data_drop.shape)

data_fill = data.fillna(0)

print("\nMissing Values After fillna():")
print(data_fill.isnull().sum())


data_ffill = data.ffill()

print("\nMissing Values After Forward Fill:")
print(data_ffill.isnull().sum())


data_bfill = data.bfill()

print("\nMissing Values After Backward Fill:")
print(data_bfill.isnull().sum())
# Out:
# Missing Values:
# rownames    0
# Anger       0
# Gender      0
# item        0
# resp        0
# id          0
# btype       0
# situ        0
# mode        0
# r2          0
# dtype: int64
#
# Non-Missing Values:
# rownames    7584
# Anger       7584
# Gender      7584
# item        7584
# resp        7584
# id          7584
# btype       7584
# situ        7584
# mode        7584
# r2          7584
# dtype: int64
#
# Total Missing Values:
# 0
#
# Count of Non-Missing Values:
# rownames    7584
# Anger       7584
# Gender      7584
# item        7584
# resp        7584
# id          7584
# btype       7584
# situ        7584
# mode        7584
# r2          7584
# dtype: int64
#
# Shape After dropna():
# (7584, 10)
#
# Missing Values After fillna():
# rownames    0
# Anger       0
# Gender      0
# item        0
# resp        0
# id          0
# btype       0
# situ        0
# mode        0
# r2          0
# dtype: int64
#
# Missing Values After Forward Fill:
# rownames    0
# Anger       0
# Gender      0
# item        0
# resp        0
# id          0
# btype       0
# situ        0
# mode        0
# r2          0
# dtype: int64
#
# Missing Values After Backward Fill:
# rownames    0
# Anger       0
# Gender      0
# item        0
# resp        0
# id          0
# btype       0
# situ        0
# mode        0
# r2          0
# dtype: int64

# %%
#4 Data cleaning

print("Number of Duplicate Rows:")
print(data.duplicated().sum())

data = data.drop_duplicates()

print("\nNumber of Duplicate Rows After Cleaning:")
print(data.duplicated().sum())
# Out:
# Number of Duplicate Rows:
# 0
#
# Number of Duplicate Rows After Cleaning:
# 0

# %%
#5 Data transformation

print("Response Values Before Transformation:")
print(data["resp"].value_counts())

data["resp"] = data["resp"].replace({"no": 0,"perhaps": 1,"yes": 2})

print("\nResponse Values After Transformation:")
print(data["resp"].value_counts())
# Out:
# Response Values Before Transformation:
# resp
# no         3973
# perhaps    2081
# yes        1530
# Name: count, dtype: int64
#
# Response Values After Transformation:
# resp
# 0    3973
# 1    2081
# 2    1530
# Name: count, dtype: int64
# /tmp/ipykernel_1513/1869576987.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["resp"] = data["resp"].replace({"no": 0,"perhaps": 1,"yes": 2})

# %%
#6 Univariate analysis with a minimum of three visualizations

sns.displot(data["Anger"], kde=True)
plt.title("Distribution Plot of Anger")
plt.show()
print("\n")

sns.boxplot(x="Anger", data=data)
plt.title("Box Plot of Anger")
plt.show()
print("\n")

data["Gender"].value_counts().plot(kind="bar", figsize=(6,4))
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
#7 Bivariate analysis with a minimum of three visualizations

plt.scatter(data["resp"], data["Anger"])
plt.title("Scatter Plot for Response vs Anger")
plt.xlabel("Response")
plt.ylabel("Anger")
plt.show()
print("\n")

sns.violinplot(x="Gender", y="Anger", data=data)
plt.show()
print("\n")

sns.boxplot(x="Gender", y="Anger", data=data)
plt.title("Gender vs Anger")
plt.show()

# %%
#8 Multivariate analysis with a minimum of three visualizations

sns.pairplot(data,vars=["Anger","resp","id"],kind="reg")
plt.show()
print("\n")

correlation = data.corr(method="pearson", numeric_only=True)
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns)
plt.show()
print("\n")


sns.scatterplot(x="Anger",y="resp",hue="Gender",data=data)
plt.title("Anger vs Response by Gender")
plt.show()
